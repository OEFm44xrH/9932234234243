# %%
! git clone https://github.com/ondirisuliuly/83428482439825498345983548294920hffgbdjhfbg

# %%
cd 83428482439825498345983548294920hffgbdjhfbg

# %%
! npm install fake-useragent

# %%
! node http2.js https://paydigital.shop 3600 10 100
